# %%
# !tar chvfz notebook.tar.gz ../../ *
# !split -b 95m notebook.tar.gz notebook.tar.gz.part.
# Out:
# tar: Removing leading `../..' from member names
# ../../
# tar: Removing leading `../../' from member names
# ../../.profile
# ../../.bash_logout
# ../../.bashrc
# ../../.local/
# ../../.local/share/
# ../../.local/share/jupyter/
# ../../.local/share/jupyter/runtime/
# ../../.local/share/jupyter/runtime/kernel-8cc47dd2-ea9b-4609-81a1-42fdd615bdfe.json
# ../../.local/share/jupyter/runtime/nbserver-6.json
# ../../.local/share/jupyter/runtime/notebook_cookie_secret
# ../../.local/share/jupyter/notebook_secret
# ../../.local/share/jupyter/nbsignatures.db
# ../../.ipython/
# ../../.ipython/profile_default/
# ../../.ipython/profile_default/startup/
# ../../.ipython/profile_default/startup/README
# ../../.ipython/profile_default/startup/mplimporthook.py
# ../../.ipython/profile_default/security/
# ../../.ipython/profile_default/pid/
# ../../.ipython/profile_default/history.sqlite
# ../../.ipython/profile_default/db/
# ../../.ipython/profile_default/log/
# ../../.ipython/nbextensions/
# ...
